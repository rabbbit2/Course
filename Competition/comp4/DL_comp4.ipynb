# %% [markdown]
# # 深度學習
#
# # 伯伯會社 第5組 Competition04 報告
#
# ## 組員:江伯耕、蔣嘉霖、周秉儒、陳炘昱

# %%
# %%
import os 
import tensorflow as tf
import numpy as np
from ple.games.flappybird import FlappyBird
from ple import PLE
import matplotlib.pyplot as plt
import copy
import wandb
from tensorflow.keras.layers import Input, Dense
import argparse
from threading import Thread, Lock
from multiprocessing import cpu_count
os.environ["SDL_VIDEODRIVER"] = "dummy"
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
cpu_count()
# Out:
# 20

# %%
#%%
tf.keras.backend.set_floatx('float32')
wandb.init(name='A3C_Dominic_CPU=1_update_interval=4000', project="DL_comp4")

# %%
import tensorflow as tf
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
    except RuntimeError as e:
        print(e)

# %% [markdown]
# # Model: A3C
#
# https://arxiv.org/pdf/1602.01783.pdf
#
# * A2C為policy method的一種，由actor更新policy distribution，由critic估計value function。
# * A3C則是A2C開多核平行進行參數更新的版本。
#
# ## 本次比賽我們採用A3C的架構，但由於多核心的training需花較長的時間，這次競賽我們交的模型只用單核(i.e. A2C)進行training，從結果來看，即使只用單核，效果也是不錯的。

# %% [markdown]
# ## (一)、Parameter
#
# * actor 和 critic的 learning rate 調小一點(小數點第四位)的training效果比較好。
#
# * update_interval的參數基本上越大越好，盡量讓bird在死亡或收集許多動作和獎勵後再進行更新。

# %%
#%%
args = {
  'gamma' : 0.95,
  'update_interval':4000,
  'actor_lr':0.0006,
  'critic_lr':0.0008,
  'entropy_beta':0,
  'reward_no_die':0,
  'reward_die':-5,
  'reward_through':1,
  'p-threshold':0.49,
  'MIN_EXPLORING_RATE':0.01
}
CUR_EPISODE = 0

# %%
#%%
class Actor:
    def __init__(self, state_dim, action_dim):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.model = self.create_model()
        self.opt = tf.keras.optimizers.RMSprop(args['actor_lr'])
        self.entropy_beta = args['entropy_beta']

    def create_model(self):
        return tf.keras.Sequential([
            tf.keras.Input((self.state_dim,)),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(self.action_dim, activation='softmax')
        ])

    def compute_loss(self, actions, logits, advantages):
        ce_loss = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=True)
        entropy_loss = tf.keras.losses.CategoricalCrossentropy(
            from_logits=True)
        actions = tf.cast(actions, tf.int32)
        policy_loss = ce_loss(
            actions, logits, sample_weight=tf.stop_gradient(advantages))
        entropy = entropy_loss(logits, logits)
        return policy_loss - self.entropy_beta * entropy

    def train(self, states, actions, advantages):
        with tf.GradientTape() as tape:
            logits = self.model(states, training=True)
            loss = self.compute_loss(
                actions, logits, advantages)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

# %%
#%%
class Critic:
    def __init__(self, state_dim):
        self.state_dim = state_dim
        self.model = self.create_model()
        self.opt = tf.keras.optimizers.RMSprop(args['critic_lr'])

    def create_model(self):
        return tf.keras.Sequential([
            tf.keras.Input((self.state_dim,)),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(1, activation='linear')
        ])

    def compute_loss(self, v_pred, td_targets):
        mse = tf.keras.losses.MeanSquaredError()
        return mse(td_targets, v_pred)

    def train(self, states, td_targets):
        with tf.GradientTape() as tape:
            v_pred = self.model(states, training=True)
            assert v_pred.shape == td_targets.shape
            loss = self.compute_loss(v_pred, tf.stop_gradient(td_targets))
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

# %%
#%%
def make_new():
    game = FlappyBird()
    env = PLE(game)
    return env

# %% [markdown]
# ## (二)、Preprocess
#
# * 我們有對TA_state做normalization的處理，最後會存進model裡，讓model在執行助教環境時，會自動進行normalization。

# %%
#%%
def TA_state(game):
    state = copy.deepcopy(game.getGameState())
    state['next_next_pipe_bottom_y'] -= state['player_y']
    state['next_next_pipe_top_y'] -= state['player_y']
    state['next_pipe_bottom_y'] -= state['player_y']
    state['next_pipe_top_y'] -= state['player_y']
    relative_state = list(state.values())
    #return the state in tensor type, with batch dimension
    relative_state = tf.convert_to_tensor(relative_state, dtype=tf.float32)
    relative_state = tf.expand_dims(relative_state, axis=0)
    return relative_state/[512,18,288,100,100,288,100,100]
    #return relative_state/[512,10,36,100,100,36,100,100]

# %%
#%%
class Agent:
    def __init__(self, env_name):
        env = make_new()
        self.env_name = env_name
        self.state_dim = TA_state(env).shape[1]
        self.action_dim = len(env.getActionSet())

        self.global_actor = Actor(self.state_dim, self.action_dim)
        self.global_critic = Critic(self.state_dim)
        #self.num_workers = cpu_count()
        self.num_workers = 1
        #self.num_workers = 1
    def train(self, max_episodes=1000000):
        workers = []
        for i in range(self.num_workers):
            env = make_new()
            workers.append(WorkerAgent(
                env, self.global_actor, self.global_critic, max_episodes))

        for worker in workers:
            worker.start()

        for worker in workers:
            worker.join()

# %% [markdown]
# ## (三)、Reward
# * 原本有嘗試更改reward，變成只要存活就給reward，但這樣容易造成機率傾斜到固定一個動作的問題(e.g. 一直no flap，reward仍一直增加，造成no flap的機率大到接近1，讓flap的可能性變很低)，後來還是維持遊戲原本的reward計算方式。

# %%
#%%
def reward_trans(reward):
    if reward == 0:
        reward = args['reward_no_die'] 
    elif reward == 1:
        reward = args['reward_through']
    elif reward == -5:
        reward = args['reward_die']
    return reward

# %% [markdown]
# ## (四)、Training
# * 可看到train到後面，reward常出現1000以上。
# * 我們嘗試在train的過程中，對actor產出動作的機率設置threshold，希望讓model能多做一點探索，結果確實能加速model train得更好，但其實沒加也可達到同樣的結果，只是需要train的episode變多。

# %%
#%%
import time
class WorkerAgent(Thread):
    def __init__(self, env, global_actor, global_critic, max_episodes):
        Thread.__init__(self)
        self.lock = Lock()
        self.env = env
        self.state_dim = TA_state(self.env).shape[1]
        self.action_dim = len(self.env.getActionSet())

        self.max_episodes = max_episodes
        self.global_actor = global_actor
        self.global_critic = global_critic
        self.actor = Actor(self.state_dim, self.action_dim)
        self.critic = Critic(self.state_dim)

        self.actor.model.set_weights(self.global_actor.model.get_weights())
        self.critic.model.set_weights(self.global_critic.model.get_weights())

    def n_step_td_target(self, rewards, next_v_value, done):
        td_targets = np.zeros_like(rewards)
        cumulative = 0
        if not done:
            cumulative = next_v_value

        for k in reversed(range(0, len(rewards))):
            cumulative = args['gamma'] * cumulative + rewards[k]
            td_targets[k] = cumulative
        return td_targets

    def advatnage(self, td_targets, baselines):
        return td_targets - baselines

    def list_to_batch(self, list):
        batch = list[0]
        for elem in list[1:]:
            batch = np.append(batch, elem, axis=0)
        return batch

    def train(self):
        global CUR_EPISODE

        while self.max_episodes >= CUR_EPISODE:
            t1 = time.time()
            state_batch = []
            action_batch = []
            reward_batch = []
            episode_reward, done = 0, False
            self.env.reset_game()
            
            state = TA_state(self.env)
            total_loss =0
            step = 0
            while not done:
                probs = self.actor.model.predict(state)

#                 if CUR_EPISODE<1000:
#                     if 0.5-abs(probs[0][0]-0.5)<max(args['MIN_EXPLORING_RATE'], min(0.5, 0.99**((CUR_EPISODE)))):
#                         if probs[0][0]>0.5:
#                             probs[0][0] = 1-max(args['MIN_EXPLORING_RATE'], min(0.5, 0.99**((CUR_EPISODE))))
#                             probs[0][1] = max(args['MIN_EXPLORING_RATE'], min(0.5, 0.99**((CUR_EPISODE))))
#                         else:
#                             probs[0][0] = max(args['MIN_EXPLORING_RATE'], min(0.5, 0.99**((CUR_EPISODE))))
#                             probs[0][1] = 1-max(args['MIN_EXPLORING_RATE'], min(0.5, 0.99**((CUR_EPISODE))))
#                     else :
#                         probs[0][0] = probs[0][0]
#                         probs[0][1] = probs[0][1]
#                 else:
#                     probs[0][0] = probs[0][0]
#                     probs[0][1] = probs[0][1]
                action = np.random.choice(self.action_dim, p=probs[0])
                #print(probs[0])
                #action = np.random.choice(self.action_dim, p=[0.5,0.5])
                reward = reward_trans(self.env.act(self.env.getActionSet()[action])) 
                step+=1
                next_state = TA_state(self.env)
                done = self.env.game_over()

                action = np.reshape(action, [1, 1])
                reward = np.reshape(reward, [1, 1])

                state_batch.append(state)
                action_batch.append(action)
                reward_batch.append(reward)

                if len(state_batch) >= args['update_interval'] or done:
                    states = self.list_to_batch(state_batch)
                    actions = self.list_to_batch(action_batch)
                    rewards = self.list_to_batch(reward_batch)

                    next_v_value = self.critic.model.predict(next_state)
                    td_targets = self.n_step_td_target(
                        rewards, next_v_value, done)
                    advantages = td_targets - self.critic.model.predict(states)
                    
                    with self.lock:
                        actor_loss = self.global_actor.train(
                            states, actions, advantages)
                        critic_loss = self.global_critic.train(
                            states, td_targets)

                        self.actor.model.set_weights(
                            self.global_actor.model.get_weights())
                        self.critic.model.set_weights(
                            self.global_critic.model.get_weights())
                    
                    total_loss+=actor_loss
                    total_loss+=critic_loss

                    state_batch = []
                    action_batch = []
                    reward_batch = []
                    td_target_batch = []
                    advatnage_batch = []

                episode_reward += reward[0][0]
                state = next_state
            if CUR_EPISODE % 1 == 0:
                t2 = time.time()
                print('EP{} EpisodeReward={} TotalLoss={} Step={} Time={}\n'.format(CUR_EPISODE, episode_reward,total_loss,step,t2-t1))
            if episode_reward >=100:
                modelactor = self.global_actor.model
                modelactor.save("/tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward="+str(episode_reward)+"_CUR_EPISODE="+str(CUR_EPISODE))
            wandb.log({'Reward': episode_reward,'Total Loss':total_loss})
            CUR_EPISODE += 1

    def run(self):
        self.train()

# %%
#%%
env_name = 'Flappy_bird_v2'
agent = Agent(env_name)
agent.train(100000)
#%%
# Out:
# EP0 EpisodeReward=-5 TotalLoss=4.128190517425537 Step=38 Time=1.0922420024871826
#
# EP1 EpisodeReward=-5 TotalLoss=2.52353835105896 Step=45 Time=0.9741809368133545
#
# EP2 EpisodeReward=-5 TotalLoss=2.382324457168579 Step=45 Time=1.0742008686065674
#
# EP3 EpisodeReward=-5 TotalLoss=1.723806381225586 Step=56 Time=1.157773494720459
#
# EP4 EpisodeReward=-5 TotalLoss=1.69681715965271 Step=48 Time=0.9412837028503418
#
# EP5 EpisodeReward=-5 TotalLoss=1.6354947090148926 Step=48 Time=1.0291063785552979
#
# EP6 EpisodeReward=-5 TotalLoss=1.1407008171081543 Step=49 Time=1.0345277786254883
#
# EP7 EpisodeReward=-5 TotalLoss=0.7829761505126953 Step=47 Time=0.945026159286499
#
# EP8 EpisodeReward=-5 TotalLoss=0.9279395341873169 Step=48 Time=0.9406614303588867
#
# EP9 EpisodeReward=-5 TotalLoss=0.7882435321807861 Step=62 Time=1.3607454299926758
#
# EP10 EpisodeReward=-5 TotalLoss=0.5492180585861206 Step=53 Time=1.308349370956421
#
# EP11 EpisodeReward=-5 TotalLoss=0.25456753373146057 Step=54 Time=1.0657684803009033
#
# EP12 EpisodeReward=-5 TotalLoss=0.8839253187179565 Step=54 Time=1.1583926677703857
#
# EP13 EpisodeReward=-5 TotalLoss=1.5113579034805298 Step=48 Time=1.075697660446167
#
# EP14 EpisodeReward=-5 TotalLoss=0.47488078474998474 Step=57 Time=1.196152687072754
#
# EP15 EpisodeReward=-5 TotalLoss=0.9287039041519165 Step=62 Time=1.2677719593048096
#
# EP16 EpisodeReward=-5 TotalLoss=0.24543918669223785 Step=54 Time=1.1351609230041504
#
# EP17 EpisodeReward=-5 TotalLoss=1.0512176752090454 Step=47 Time=0.9847841262817383
#
# EP18 EpisodeReward=-5 TotalLoss=0.566091001033783 Step=46 Time=0.9285533428192139
#
# EP19 EpisodeReward=-5 TotalLoss=1.9201059341430664 Step=62 Time=1.287346601486206
#
# EP20 EpisodeReward=-5 TotalLoss=0.5054020285606384 Step=57 Time=1.1749048233032227
#
# EP21 EpisodeReward=-5 TotalLoss=1.693770170211792 Step=53 Time=1.2652864456176758
#
# EP22 EpisodeReward=-5 TotalLoss=0.6116817593574524 Step=51 Time=1.0667526721954346
#
# EP23 EpisodeReward=-5 TotalLoss=0.12768690288066864 Step=42 Time=0.8152990341186523
#
# EP24 EpisodeReward=-5 TotalLoss=0.9886012077331543 Step=51 Time=1.0786328315734863
#
# EP25 EpisodeReward=-5 TotalLoss=0.25655531883239746 Step=46 Time=0.9700901508331299
#
# EP26 EpisodeReward=-5 TotalLoss=0.5457815527915955 Step=52 Time=1.127535343170166
#
# EP27 EpisodeReward=-5 TotalLoss=0.14602741599082947 Step=61 Time=1.2015302181243896
#
# EP28 EpisodeReward=-5 TotalLoss=0.2184632122516632 Step=62 Time=1.3757994174957275
#
# EP29 EpisodeReward=-5 TotalLoss=1.1097416877746582 Step=49 Time=1.0583605766296387
#
# EP30 EpisodeReward=-5 TotalLoss=0.3462979197502136 Step=52 Time=1.0501275062561035
#
# EP31 EpisodeReward=-5 TotalLoss=0.3351614475250244 Step=50 Time=1.0855433940887451
#
# EP32 EpisodeReward=-5 TotalLoss=0.017622053623199463 Step=50 Time=0.9727826118469238
#
# EP33 EpisodeReward=-5 TotalLoss=2.6006593704223633 Step=62 Time=1.4707767963409424
#
# EP34 EpisodeReward=-5 TotalLoss=0.06794482469558716 Step=47 Time=0.8779895305633545
#
# EP35 EpisodeReward=-5 TotalLoss=0.9530547857284546 Step=62 Time=1.3781225681304932
#
# EP36 EpisodeReward=-5 TotalLoss=1.0249452590942383 Step=50 Time=1.0233983993530273
#
# EP37 EpisodeReward=-5 TotalLoss=0.4923470914363861 Step=62 Time=1.2681810855865479
#
# EP38 EpisodeReward=-5 TotalLoss=1.394803524017334 Step=53 Time=0.9888131618499756
#
# EP39 EpisodeReward=-5 TotalLoss=0.36858779191970825 Step=55 Time=1.2042839527130127
#
# EP40 EpisodeReward=-5 TotalLoss=0.2674083709716797 Step=36 Time=0.7478761672973633
#
# EP41 EpisodeReward=-5 TotalLoss=1.1465437412261963 Step=45 Time=0.9344677925109863
#
# EP42 EpisodeReward=-5 TotalLoss=0.09054477512836456 Step=49 Time=1.0225729942321777
#
# EP43 EpisodeReward=-5 TotalLoss=1.4058070182800293 Step=45 Time=0.9357662200927734
#
# EP44 EpisodeReward=-5 TotalLoss=0.8372735977172852 Step=55 Time=1.0985779762268066
#
# EP45 EpisodeReward=-5 TotalLoss=1.7207636833190918 Step=51 Time=1.1964735984802246
#
# EP46 EpisodeReward=-5 TotalLoss=0.3414229452610016 Step=47 Time=0.9589729309082031
#
# EP47 EpisodeReward=-5 TotalLoss=0.5456532835960388 Step=45 Time=0.9657318592071533
#
# EP48 EpisodeReward=-5 TotalLoss=1.4628710746765137 Step=47 Time=0.9389641284942627
#
# EP49 EpisodeReward=-5 TotalLoss=0.6649830341339111 Step=62 Time=1.2394206523895264
#
# EP50 EpisodeReward=-5 TotalLoss=0.5348740816116333 Step=52 Time=1.194737434387207
#
# EP51 EpisodeReward=-5 TotalLoss=1.1234050989151 Step=55 Time=1.2310245037078857
#
# EP52 EpisodeReward=-5 TotalLoss=0.2120082676410675 Step=51 Time=1.106628179550171
#
# EP53 EpisodeReward=-5 TotalLoss=0.9500946402549744 Step=50 Time=1.0840506553649902
#
# EP54 EpisodeReward=-5 TotalLoss=0.498456746339798 Step=62 Time=1.3764739036560059
#
# EP55 EpisodeReward=-5 TotalLoss=0.2117617130279541 Step=59 Time=1.195486307144165
#
# EP56 EpisodeReward=-5 TotalLoss=0.43392884731292725 Step=46 Time=0.9659912586212158
#
# EP57 EpisodeReward=-5 TotalLoss=1.0681205987930298 Step=56 Time=1.3056199550628662
#
# EP58 EpisodeReward=-5 TotalLoss=0.21827375888824463 Step=43 Time=0.8694155216217041
#
# EP59 EpisodeReward=-5 TotalLoss=0.09426160156726837 Step=56 Time=1.183332920074463
#
# EP60 EpisodeReward=-5 TotalLoss=0.2745349705219269 Step=51 Time=1.0318918228149414
#
# EP61 EpisodeReward=-5 TotalLoss=1.2323739528656006 Step=56 Time=1.3036575317382812
#
# EP62 EpisodeReward=-5 TotalLoss=0.5863693356513977 Step=50 Time=1.0076920986175537
#
# EP63 EpisodeReward=-5 TotalLoss=2.998138189315796 Step=61 Time=1.3102047443389893
#
# EP64 EpisodeReward=-5 TotalLoss=0.10759761929512024 Step=49 Time=1.015495777130127
#
# EP65 EpisodeReward=-5 TotalLoss=0.2385139763355255 Step=51 Time=1.0730860233306885
#
# EP66 EpisodeReward=-5 TotalLoss=0.35278600454330444 Step=59 Time=1.2819461822509766
#
# EP67 EpisodeReward=-5 TotalLoss=0.17335979640483856 Step=51 Time=1.0914974212646484
#
# EP68 EpisodeReward=-5 TotalLoss=0.17975153028964996 Step=62 Time=1.4425444602966309
#
# EP69 EpisodeReward=-5 TotalLoss=1.6850143671035767 Step=62 Time=1.2751963138580322
#
# EP70 EpisodeReward=-5 TotalLoss=0.0802982747554779 Step=47 Time=1.0495100021362305
#
# EP71 EpisodeReward=-5 TotalLoss=0.0037228167057037354 Step=37 Time=0.7929205894470215
#
# EP72 EpisodeReward=-5 TotalLoss=0.062495261430740356 Step=54 Time=1.0950264930725098
#
# EP73 EpisodeReward=-5 TotalLoss=0.09185902029275894 Step=48 Time=0.970095157623291
#
# EP74 EpisodeReward=-5 TotalLoss=0.7619601488113403 Step=45 Time=1.0397367477416992
#
# EP75 EpisodeReward=-5 TotalLoss=0.13050726056098938 Step=42 Time=0.8502132892608643
#
# EP76 EpisodeReward=-5 TotalLoss=0.661164402961731 Step=47 Time=0.9754948616027832
#
# EP77 EpisodeReward=-5 TotalLoss=1.034184217453003 Step=62 Time=1.2658345699310303
#
# EP78 EpisodeReward=-5 TotalLoss=0.5885410904884338 Step=54 Time=1.0479650497436523
#
# EP79 EpisodeReward=-5 TotalLoss=1.2212233543395996 Step=53 Time=1.13450026512146
#
# EP80 EpisodeReward=-5 TotalLoss=0.23235049843788147 Step=44 Time=0.9940989017486572
#
# EP81 EpisodeReward=-5 TotalLoss=0.527470052242279 Step=59 Time=1.3686108589172363
#
# EP82 EpisodeReward=-5 TotalLoss=1.2907145023345947 Step=52 Time=1.0179405212402344
#
# EP83 EpisodeReward=-5 TotalLoss=1.5160003900527954 Step=50 Time=1.1375491619110107
#
# EP84 EpisodeReward=-5 TotalLoss=0.3980443477630615 Step=62 Time=1.298429012298584
#
# EP85 EpisodeReward=-5 TotalLoss=0.7166666984558105 Step=54 Time=1.0356340408325195
#
# EP86 EpisodeReward=-5 TotalLoss=0.30726924538612366 Step=53 Time=1.1036784648895264
#
# EP87 EpisodeReward=-5 TotalLoss=0.16284310817718506 Step=58 Time=1.307037591934204
#
# EP88 EpisodeReward=-5 TotalLoss=0.18531322479248047 Step=57 Time=1.1217138767242432
#
# EP89 EpisodeReward=-5 TotalLoss=0.27971717715263367 Step=62 Time=1.2578999996185303
#
# EP90 EpisodeReward=-5 TotalLoss=0.5944548845291138 Step=50 Time=1.0913493633270264
#
# EP91 EpisodeReward=-5 TotalLoss=0.2755967974662781 Step=57 Time=1.2045819759368896
#
# EP92 EpisodeReward=-5 TotalLoss=0.40540093183517456 Step=47 Time=1.1767196655273438
#
# EP93 EpisodeReward=-5 TotalLoss=1.7017650604248047 Step=55 Time=1.1557021141052246
#
# EP94 EpisodeReward=-5 TotalLoss=0.11024414002895355 Step=62 Time=1.2771177291870117
#
# EP95 EpisodeReward=-5 TotalLoss=0.31552520394325256 Step=56 Time=1.1924726963043213
#
# EP96 EpisodeReward=-5 TotalLoss=0.5606262683868408 Step=62 Time=1.257678508758545
#
# EP97 EpisodeReward=-5 TotalLoss=0.318436861038208 Step=56 Time=1.2601737976074219
#
# EP98 EpisodeReward=-5 TotalLoss=0.4263136386871338 Step=60 Time=1.3221375942230225
#
# EP99 EpisodeReward=-5 TotalLoss=0.30877381563186646 Step=62 Time=1.31321120262146
#
# EP100 EpisodeReward=-5 TotalLoss=0.21051627397537231 Step=44 Time=0.9438860416412354
#
# EP101 EpisodeReward=-5 TotalLoss=0.05900106951594353 Step=43 Time=1.0105860233306885
#
# EP102 EpisodeReward=-5 TotalLoss=0.49098435044288635 Step=59 Time=1.1915287971496582
#
# EP103 EpisodeReward=-5 TotalLoss=0.6051037907600403 Step=48 Time=1.1665656566619873
#
# EP104 EpisodeReward=-5 TotalLoss=0.5367888808250427 Step=52 Time=1.0973303318023682
#
# EP105 EpisodeReward=-5 TotalLoss=1.0308338403701782 Step=62 Time=1.2729904651641846
#
# EP106 EpisodeReward=-5 TotalLoss=0.18262767791748047 Step=40 Time=0.8606104850769043
#
# EP107 EpisodeReward=-5 TotalLoss=0.14826840162277222 Step=59 Time=1.2616641521453857
#
# EP108 EpisodeReward=-5 TotalLoss=0.23156620562076569 Step=57 Time=1.2502038478851318
#
# EP109 EpisodeReward=-5 TotalLoss=1.3786669969558716 Step=59 Time=1.2297227382659912
#
# EP110 EpisodeReward=-5 TotalLoss=0.19886115193367004 Step=62 Time=1.2592899799346924
#
# EP111 EpisodeReward=-5 TotalLoss=1.1392978429794312 Step=57 Time=1.2609789371490479
#
# EP112 EpisodeReward=-5 TotalLoss=0.21052305400371552 Step=55 Time=1.1046791076660156
#
# EP113 EpisodeReward=-5 TotalLoss=0.6488516926765442 Step=54 Time=1.0502214431762695
#
# EP114 EpisodeReward=-5 TotalLoss=0.3876766860485077 Step=62 Time=1.5357129573822021
#
# EP115 EpisodeReward=-5 TotalLoss=-0.0022404640913009644 Step=51 Time=1.0324573516845703
#
# EP116 EpisodeReward=-5 TotalLoss=1.6543341875076294 Step=54 Time=1.1242609024047852
#
# EP117 EpisodeReward=-5 TotalLoss=0.13707199692726135 Step=53 Time=1.1500189304351807
#
# EP118 EpisodeReward=-5 TotalLoss=0.302656352519989 Step=43 Time=0.9446976184844971
#
# EP119 EpisodeReward=-5 TotalLoss=0.16677844524383545 Step=57 Time=1.1928822994232178
#
# EP120 EpisodeReward=-5 TotalLoss=0.07476804405450821 Step=46 Time=0.9739952087402344
#
# EP121 EpisodeReward=-5 TotalLoss=0.8182692527770996 Step=53 Time=0.9821782112121582
#
# EP122 EpisodeReward=-5 TotalLoss=0.38801243901252747 Step=62 Time=1.3326737880706787
#
# EP123 EpisodeReward=-5 TotalLoss=0.42970114946365356 Step=62 Time=1.215940237045288
#
# EP124 EpisodeReward=-5 TotalLoss=0.33941328525543213 Step=62 Time=1.3151767253875732
#
# EP125 EpisodeReward=-5 TotalLoss=0.1846039891242981 Step=55 Time=1.2327427864074707
#
# EP126 EpisodeReward=-5 TotalLoss=0.13462130725383759 Step=59 Time=1.3164968490600586
#
# EP127 EpisodeReward=-5 TotalLoss=0.3865703046321869 Step=59 Time=1.2022686004638672
#
# EP128 EpisodeReward=-5 TotalLoss=0.16738182306289673 Step=56 Time=1.1993210315704346
#
# EP129 EpisodeReward=-5 TotalLoss=4.201598644256592 Step=57 Time=1.2641746997833252
#
# EP130 EpisodeReward=-5 TotalLoss=0.14331766963005066 Step=57 Time=1.1418993473052979
#
# EP131 EpisodeReward=-5 TotalLoss=2.6791858673095703 Step=62 Time=1.3100063800811768
#
# EP132 EpisodeReward=-5 TotalLoss=0.4629862308502197 Step=59 Time=1.2896974086761475
#
# EP133 EpisodeReward=-5 TotalLoss=0.17150144279003143 Step=59 Time=1.2904210090637207
#
# EP134 EpisodeReward=-5 TotalLoss=0.20585504174232483 Step=62 Time=1.238046646118164
#
# EP135 EpisodeReward=-5 TotalLoss=0.08858363330364227 Step=62 Time=1.2710964679718018
#
# EP136 EpisodeReward=-5 TotalLoss=0.2123943716287613 Step=62 Time=1.4424433708190918
#
# EP137 EpisodeReward=-5 TotalLoss=0.10292689502239227 Step=49 Time=0.9502537250518799
#
# EP138 EpisodeReward=-5 TotalLoss=0.46759480237960815 Step=62 Time=1.2826831340789795
#
# EP139 EpisodeReward=-5 TotalLoss=1.4679375886917114 Step=62 Time=1.3001785278320312
#
# EP140 EpisodeReward=-5 TotalLoss=0.125688374042511 Step=58 Time=1.1883082389831543
#
# EP141 EpisodeReward=-5 TotalLoss=0.08701488375663757 Step=55 Time=1.2255558967590332
#
# EP142 EpisodeReward=-5 TotalLoss=0.7259734869003296 Step=60 Time=1.257291316986084
#
# EP143 EpisodeReward=-5 TotalLoss=0.6676023602485657 Step=62 Time=1.2621843814849854
#
# EP144 EpisodeReward=-5 TotalLoss=0.44496917724609375 Step=62 Time=1.4856054782867432
#
# EP145 EpisodeReward=-5 TotalLoss=0.23130933940410614 Step=62 Time=1.2811830043792725
#
# EP146 EpisodeReward=-5 TotalLoss=0.20100848376750946 Step=62 Time=1.3080189228057861
#
# EP147 EpisodeReward=-5 TotalLoss=0.5890874266624451 Step=62 Time=1.522052526473999
#
# EP148 EpisodeReward=-5 TotalLoss=0.1666695922613144 Step=62 Time=1.377403736114502
#
# EP149 EpisodeReward=-5 TotalLoss=0.49582594633102417 Step=57 Time=1.1737151145935059
#
# EP150 EpisodeReward=-5 TotalLoss=0.1648118942975998 Step=59 Time=1.2121071815490723
#
# EP151 EpisodeReward=-5 TotalLoss=1.248772382736206 Step=62 Time=1.311600923538208
#
# EP152 EpisodeReward=-5 TotalLoss=0.2640571892261505 Step=52 Time=1.058809757232666
#
# EP153 EpisodeReward=-5 TotalLoss=1.3306009769439697 Step=55 Time=1.0707337856292725
#
# EP154 EpisodeReward=-5 TotalLoss=0.19861748814582825 Step=54 Time=1.2065684795379639
#
# EP155 EpisodeReward=-5 TotalLoss=0.5063627362251282 Step=61 Time=1.3238487243652344
#
# EP156 EpisodeReward=-5 TotalLoss=0.12455309927463531 Step=62 Time=1.285383939743042
#
# EP157 EpisodeReward=-5 TotalLoss=0.3749636113643646 Step=62 Time=1.4645273685455322
#
# EP158 EpisodeReward=-5 TotalLoss=0.8199756145477295 Step=54 Time=1.1884942054748535
#
# EP159 EpisodeReward=-5 TotalLoss=0.5340390205383301 Step=62 Time=1.2546448707580566
#
# EP160 EpisodeReward=-5 TotalLoss=0.3810955286026001 Step=52 Time=1.2169089317321777
#
# EP161 EpisodeReward=-5 TotalLoss=0.2656932473182678 Step=50 Time=1.104414939880371
#
# EP162 EpisodeReward=-5 TotalLoss=0.7675167918205261 Step=55 Time=1.0898361206054688
#
# EP163 EpisodeReward=-5 TotalLoss=0.11758184432983398 Step=59 Time=1.1388390064239502
#
# EP164 EpisodeReward=-5 TotalLoss=0.17985251545906067 Step=62 Time=1.3694660663604736
#
# EP165 EpisodeReward=-5 TotalLoss=0.2971653640270233 Step=59 Time=1.2726664543151855
#
# EP166 EpisodeReward=-5 TotalLoss=0.2602473199367523 Step=56 Time=1.1654837131500244
#
# EP167 EpisodeReward=-5 TotalLoss=0.09618258476257324 Step=54 Time=1.1176693439483643
#
# EP168 EpisodeReward=-5 TotalLoss=0.11481456458568573 Step=56 Time=1.3974831104278564
#
# EP169 EpisodeReward=-5 TotalLoss=0.18068361282348633 Step=51 Time=1.1425518989562988
#
# EP170 EpisodeReward=-5 TotalLoss=0.6836965084075928 Step=62 Time=1.3121283054351807
#
# EP171 EpisodeReward=-5 TotalLoss=0.10032812505960464 Step=60 Time=1.2982666492462158
#
# EP172 EpisodeReward=-5 TotalLoss=0.15075097978115082 Step=62 Time=1.2567787170410156
#
# EP173 EpisodeReward=-5 TotalLoss=0.7280770540237427 Step=58 Time=1.3203635215759277
#
# EP174 EpisodeReward=-5 TotalLoss=0.7342171669006348 Step=62 Time=1.3745572566986084
#
# EP175 EpisodeReward=-5 TotalLoss=0.17523616552352905 Step=62 Time=1.2110564708709717
#
# EP176 EpisodeReward=-5 TotalLoss=0.1971098780632019 Step=59 Time=1.1896798610687256
#
# EP177 EpisodeReward=-5 TotalLoss=1.2704333066940308 Step=62 Time=1.3725404739379883
#
# EP178 EpisodeReward=-5 TotalLoss=1.1109511852264404 Step=62 Time=1.332024097442627
#
# EP179 EpisodeReward=-5 TotalLoss=0.2723124027252197 Step=58 Time=1.2907562255859375
#
# EP180 EpisodeReward=-5 TotalLoss=0.2639143466949463 Step=58 Time=1.2549018859863281
#
# EP181 EpisodeReward=-5 TotalLoss=0.2933184504508972 Step=62 Time=1.2698073387145996
#
# EP182 EpisodeReward=-5 TotalLoss=0.36007851362228394 Step=62 Time=1.1710329055786133
#
# EP183 EpisodeReward=-5 TotalLoss=0.5528962016105652 Step=54 Time=1.1588096618652344
#
# EP184 EpisodeReward=-5 TotalLoss=0.20370084047317505 Step=53 Time=1.1112761497497559
#
# EP185 EpisodeReward=-5 TotalLoss=0.4037330746650696 Step=61 Time=1.2990925312042236
#
# EP186 EpisodeReward=-5 TotalLoss=0.18250985443592072 Step=62 Time=1.3143224716186523
#
# EP187 EpisodeReward=-5 TotalLoss=0.1443859189748764 Step=59 Time=1.247056007385254
#
# EP188 EpisodeReward=-5 TotalLoss=0.21350952982902527 Step=61 Time=1.3421766757965088
#
# EP189 EpisodeReward=-5 TotalLoss=0.6466756463050842 Step=53 Time=1.3412489891052246
#
# EP190 EpisodeReward=-5 TotalLoss=0.2117576152086258 Step=62 Time=1.2772364616394043
#
# EP191 EpisodeReward=-5 TotalLoss=0.16047263145446777 Step=53 Time=1.0752177238464355
#
# EP192 EpisodeReward=-5 TotalLoss=0.43171125650405884 Step=62 Time=1.223802089691162
#
# EP193 EpisodeReward=-5 TotalLoss=0.10997976362705231 Step=61 Time=1.3210854530334473
#
# EP194 EpisodeReward=-5 TotalLoss=1.023060917854309 Step=56 Time=1.2438170909881592
#
# EP195 EpisodeReward=-5 TotalLoss=0.48904943466186523 Step=60 Time=1.1264393329620361
#
# EP196 EpisodeReward=-5 TotalLoss=0.657558023929596 Step=61 Time=1.230954885482788
#
# EP197 EpisodeReward=-5 TotalLoss=0.163790762424469 Step=62 Time=1.3630774021148682
#
# EP198 EpisodeReward=-5 TotalLoss=0.07061871886253357 Step=55 Time=1.1041169166564941
#
# EP199 EpisodeReward=-5 TotalLoss=0.8409353494644165 Step=57 Time=1.188443899154663
#
# EP200 EpisodeReward=-5 TotalLoss=0.43114596605300903 Step=62 Time=1.440260887145996
#
# EP201 EpisodeReward=-5 TotalLoss=0.6310991048812866 Step=62 Time=1.255413293838501
#
# EP202 EpisodeReward=-5 TotalLoss=0.21909582614898682 Step=62 Time=1.2220308780670166
#
# EP203 EpisodeReward=-4 TotalLoss=0.35481059551239014 Step=67 Time=1.540036916732788
#
# EP204 EpisodeReward=-5 TotalLoss=1.0865591764450073 Step=55 Time=1.1175038814544678
#
# EP205 EpisodeReward=-5 TotalLoss=0.20679354667663574 Step=62 Time=1.3164095878601074
#
# EP206 EpisodeReward=-5 TotalLoss=0.7751832008361816 Step=62 Time=1.2923500537872314
#
# EP207 EpisodeReward=-5 TotalLoss=2.742340564727783 Step=60 Time=1.2639210224151611
#
# EP208 EpisodeReward=-5 TotalLoss=0.9092459082603455 Step=62 Time=1.2129335403442383
#
# EP209 EpisodeReward=-5 TotalLoss=0.14452655613422394 Step=60 Time=1.2057178020477295
#
# EP210 EpisodeReward=-5 TotalLoss=0.5744997262954712 Step=62 Time=1.52870512008667
#
# EP211 EpisodeReward=-5 TotalLoss=0.16519199311733246 Step=61 Time=1.205878496170044
#
# EP212 EpisodeReward=-5 TotalLoss=0.19301024079322815 Step=62 Time=1.3677241802215576
#
# EP213 EpisodeReward=-5 TotalLoss=0.16074025630950928 Step=62 Time=1.2893030643463135
#
# EP214 EpisodeReward=-5 TotalLoss=0.739475667476654 Step=59 Time=1.2559521198272705
#
# EP215 EpisodeReward=-5 TotalLoss=0.2096017301082611 Step=62 Time=1.2823593616485596
#
# EP216 EpisodeReward=-5 TotalLoss=0.23356127738952637 Step=62 Time=1.4188456535339355
#
# EP217 EpisodeReward=-5 TotalLoss=0.545210063457489 Step=62 Time=1.221724271774292
#
# EP218 EpisodeReward=-5 TotalLoss=0.24277207255363464 Step=62 Time=1.333362340927124
#
# EP219 EpisodeReward=-5 TotalLoss=0.3471187651157379 Step=62 Time=1.2929973602294922
#
# EP220 EpisodeReward=-5 TotalLoss=1.4989862442016602 Step=59 Time=1.3566818237304688
#
# EP221 EpisodeReward=-5 TotalLoss=0.22363749146461487 Step=62 Time=1.2226028442382812
#
# EP222 EpisodeReward=-5 TotalLoss=0.15252412855625153 Step=61 Time=1.2915849685668945
#
# EP223 EpisodeReward=-5 TotalLoss=0.7751664519309998 Step=59 Time=1.2988908290863037
#
# EP224 EpisodeReward=-5 TotalLoss=0.2427564114332199 Step=59 Time=1.1763930320739746
#
# EP225 EpisodeReward=-5 TotalLoss=0.2242555320262909 Step=62 Time=1.3142645359039307
#
# EP226 EpisodeReward=-5 TotalLoss=0.9989993572235107 Step=63 Time=1.2840709686279297
#
# EP227 EpisodeReward=-5 TotalLoss=0.20199885964393616 Step=60 Time=1.2159819602966309
#
# EP228 EpisodeReward=-5 TotalLoss=1.7282462120056152 Step=62 Time=1.3413562774658203
#
# EP229 EpisodeReward=-5 TotalLoss=0.566175103187561 Step=62 Time=1.3108587265014648
#
# EP230 EpisodeReward=-5 TotalLoss=0.2753758430480957 Step=61 Time=1.3983430862426758
#
# EP231 EpisodeReward=-5 TotalLoss=0.2037874460220337 Step=62 Time=1.3274204730987549
#
# EP232 EpisodeReward=-5 TotalLoss=1.1048343181610107 Step=64 Time=1.331216812133789
#
# EP233 EpisodeReward=-5 TotalLoss=0.8141184449195862 Step=62 Time=1.2697029113769531
#
# EP234 EpisodeReward=-5 TotalLoss=0.2799385190010071 Step=62 Time=1.4330322742462158
#
# EP235 EpisodeReward=-5 TotalLoss=0.6913060545921326 Step=62 Time=1.3337125778198242
#
# EP236 EpisodeReward=-5 TotalLoss=0.4061458110809326 Step=62 Time=1.2372307777404785
#
# EP237 EpisodeReward=-5 TotalLoss=0.23599842190742493 Step=62 Time=1.3006231784820557
#
# EP238 EpisodeReward=-5 TotalLoss=0.23531761765480042 Step=57 Time=1.1601123809814453
#
# EP239 EpisodeReward=-4 TotalLoss=0.405311644077301 Step=73 Time=1.4941892623901367
#
# EP240 EpisodeReward=-5 TotalLoss=0.15641120076179504 Step=62 Time=1.5376322269439697
#
# EP241 EpisodeReward=-5 TotalLoss=0.29479819536209106 Step=58 Time=1.1295301914215088
#
# EP242 EpisodeReward=-5 TotalLoss=0.06555582582950592 Step=62 Time=1.2348623275756836
#
# EP243 EpisodeReward=-5 TotalLoss=0.10609402507543564 Step=62 Time=1.316136360168457
#
# EP244 EpisodeReward=-5 TotalLoss=0.36405467987060547 Step=62 Time=1.2468054294586182
#
# EP245 EpisodeReward=-5 TotalLoss=0.33863648772239685 Step=62 Time=1.3061907291412354
#
# EP246 EpisodeReward=-5 TotalLoss=0.46730729937553406 Step=62 Time=1.291518211364746
#
# EP247 EpisodeReward=-5 TotalLoss=0.18498152494430542 Step=62 Time=1.4094724655151367
#
# EP248 EpisodeReward=-5 TotalLoss=0.11092312633991241 Step=62 Time=1.2629201412200928
#
# EP249 EpisodeReward=-5 TotalLoss=1.144080638885498 Step=62 Time=1.2179648876190186
#
# EP250 EpisodeReward=-5 TotalLoss=1.1533339023590088 Step=62 Time=1.4482886791229248
#
# EP251 EpisodeReward=-5 TotalLoss=0.14552031457424164 Step=59 Time=1.2293930053710938
#
# EP252 EpisodeReward=-5 TotalLoss=0.6040104031562805 Step=62 Time=1.2201495170593262
#
# EP253 EpisodeReward=-5 TotalLoss=0.240431010723114 Step=62 Time=1.3576855659484863
#
# EP254 EpisodeReward=-5 TotalLoss=1.1901921033859253 Step=62 Time=1.2561137676239014
#
# EP255 EpisodeReward=-5 TotalLoss=0.5405829548835754 Step=57 Time=1.19321608543396
#
# EP256 EpisodeReward=-5 TotalLoss=0.14776508510112762 Step=62 Time=1.2849783897399902
#
# EP257 EpisodeReward=-5 TotalLoss=0.38842663168907166 Step=62 Time=1.3187055587768555
#
# EP258 EpisodeReward=-5 TotalLoss=0.9792768359184265 Step=58 Time=1.3072059154510498
#
# EP259 EpisodeReward=-5 TotalLoss=0.1510676145553589 Step=62 Time=1.2811903953552246
#
# EP260 EpisodeReward=-5 TotalLoss=0.315481036901474 Step=59 Time=1.3193604946136475
#
# EP261 EpisodeReward=-5 TotalLoss=0.09964777529239655 Step=55 Time=1.3030121326446533
#
# EP262 EpisodeReward=-5 TotalLoss=0.18889500200748444 Step=62 Time=1.2261581420898438
#
# EP263 EpisodeReward=-5 TotalLoss=0.27249380946159363 Step=49 Time=1.043644905090332
#
# EP264 EpisodeReward=-5 TotalLoss=2.650751829147339 Step=59 Time=1.2164859771728516
#
# EP265 EpisodeReward=-5 TotalLoss=0.10340136289596558 Step=62 Time=1.3123202323913574
#
# EP266 EpisodeReward=-5 TotalLoss=0.2686525583267212 Step=62 Time=1.3374171257019043
#
# EP267 EpisodeReward=-5 TotalLoss=0.4195803999900818 Step=62 Time=1.4010367393493652
#
# EP268 EpisodeReward=-5 TotalLoss=0.28528642654418945 Step=62 Time=1.1706840991973877
#
# EP269 EpisodeReward=-5 TotalLoss=0.4316249489784241 Step=62 Time=1.300489902496338
#
# EP270 EpisodeReward=-5 TotalLoss=0.21711274981498718 Step=62 Time=1.4059982299804688
#
# EP271 EpisodeReward=-5 TotalLoss=0.4661543667316437 Step=56 Time=1.3247699737548828
#
# EP272 EpisodeReward=-5 TotalLoss=0.363564133644104 Step=62 Time=1.3623244762420654
#
# EP273 EpisodeReward=-5 TotalLoss=0.5691081881523132 Step=62 Time=1.4118812084197998
#
# EP274 EpisodeReward=-5 TotalLoss=0.3791504502296448 Step=62 Time=1.1569759845733643
#
# EP275 EpisodeReward=-5 TotalLoss=0.2289823293685913 Step=58 Time=1.2315778732299805
#
# EP276 EpisodeReward=-5 TotalLoss=0.3475385010242462 Step=57 Time=1.2124652862548828
#
# EP277 EpisodeReward=-5 TotalLoss=0.17161032557487488 Step=56 Time=1.115027666091919
#
# EP278 EpisodeReward=-5 TotalLoss=0.18109780550003052 Step=62 Time=1.2904839515686035
#
# EP279 EpisodeReward=-5 TotalLoss=0.310360312461853 Step=62 Time=1.317068099975586
#
# EP280 EpisodeReward=-5 TotalLoss=0.12606076896190643 Step=52 Time=1.1042985916137695
#
# EP281 EpisodeReward=-5 TotalLoss=0.13181540369987488 Step=57 Time=1.27593994140625
#
# EP282 EpisodeReward=-5 TotalLoss=0.1589546501636505 Step=62 Time=1.5221762657165527
#
# EP283 EpisodeReward=-5 TotalLoss=0.24187032878398895 Step=60 Time=1.2674055099487305
#
# EP284 EpisodeReward=-5 TotalLoss=0.31675416231155396 Step=62 Time=1.1901288032531738
#
# EP285 EpisodeReward=-5 TotalLoss=0.507463812828064 Step=62 Time=1.3073256015777588
#
# EP286 EpisodeReward=-5 TotalLoss=0.3800627589225769 Step=62 Time=1.2675182819366455
#
# EP287 EpisodeReward=-5 TotalLoss=0.2215099334716797 Step=58 Time=1.1889643669128418
#
# EP288 EpisodeReward=-5 TotalLoss=0.28394198417663574 Step=55 Time=1.1138410568237305
#
# EP289 EpisodeReward=-5 TotalLoss=0.5080969333648682 Step=58 Time=1.368537425994873
#
# EP290 EpisodeReward=-5 TotalLoss=0.21272219717502594 Step=57 Time=1.2021141052246094
#
# EP291 EpisodeReward=-4 TotalLoss=0.2649427354335785 Step=68 Time=1.3776154518127441
#
# EP292 EpisodeReward=-4 TotalLoss=0.3102760910987854 Step=68 Time=1.589630126953125
#
# EP293 EpisodeReward=-5 TotalLoss=0.9505847692489624 Step=61 Time=1.2421927452087402
#
# EP294 EpisodeReward=-5 TotalLoss=0.5734115839004517 Step=62 Time=1.2564752101898193
#
# EP295 EpisodeReward=-5 TotalLoss=0.27685314416885376 Step=62 Time=1.283034086227417
#
# EP296 EpisodeReward=-5 TotalLoss=0.28963643312454224 Step=62 Time=1.3653218746185303
#
# EP297 EpisodeReward=-5 TotalLoss=0.20747937262058258 Step=61 Time=1.2827343940734863
#
# EP298 EpisodeReward=-5 TotalLoss=0.17518384754657745 Step=55 Time=1.238786220550537
#
# EP299 EpisodeReward=-5 TotalLoss=0.24950681626796722 Step=62 Time=1.2792410850524902
#
# EP300 EpisodeReward=-5 TotalLoss=0.16552308201789856 Step=57 Time=1.1854872703552246
#
# EP301 EpisodeReward=-5 TotalLoss=0.17521317303180695 Step=61 Time=1.3002865314483643
#
# EP302 EpisodeReward=-5 TotalLoss=1.659043788909912 Step=58 Time=1.3315799236297607
#
# EP303 EpisodeReward=-5 TotalLoss=0.11291557550430298 Step=58 Time=1.1249442100524902
#
# EP304 EpisodeReward=-5 TotalLoss=0.9150681495666504 Step=62 Time=1.3630061149597168
#
# EP305 EpisodeReward=-5 TotalLoss=0.15620402991771698 Step=58 Time=1.2709510326385498
#
# EP306 EpisodeReward=-5 TotalLoss=0.3960745334625244 Step=62 Time=1.2427008152008057
#
# EP307 EpisodeReward=-5 TotalLoss=0.11168547719717026 Step=62 Time=1.2587130069732666
#
# EP308 EpisodeReward=-5 TotalLoss=0.2139354944229126 Step=62 Time=1.371001958847046
#
# EP309 EpisodeReward=-5 TotalLoss=0.2377917766571045 Step=62 Time=1.1612370014190674
#
# EP310 EpisodeReward=-5 TotalLoss=0.11266140639781952 Step=62 Time=1.2244038581848145
#
# EP311 EpisodeReward=-5 TotalLoss=0.15913665294647217 Step=62 Time=1.3420898914337158
#
# EP312 EpisodeReward=-5 TotalLoss=0.46134501695632935 Step=62 Time=1.2674078941345215
#
# EP313 EpisodeReward=-5 TotalLoss=0.2764691710472107 Step=62 Time=1.4073235988616943
#
# EP314 EpisodeReward=-5 TotalLoss=1.1177394390106201 Step=62 Time=1.3825323581695557
#
# EP315 EpisodeReward=-5 TotalLoss=0.0715240091085434 Step=61 Time=1.2989451885223389
#
# EP316 EpisodeReward=-5 TotalLoss=0.16815853118896484 Step=62 Time=1.248410701751709
#
# EP317 EpisodeReward=-5 TotalLoss=0.2219814956188202 Step=54 Time=1.122244119644165
#
# EP318 EpisodeReward=-5 TotalLoss=0.09318403899669647 Step=62 Time=1.30963134765625
#
# EP319 EpisodeReward=-5 TotalLoss=0.6457167863845825 Step=62 Time=1.153738260269165
#
# EP320 EpisodeReward=-5 TotalLoss=0.10548874735832214 Step=62 Time=1.387732744216919
#
# EP321 EpisodeReward=-5 TotalLoss=0.07385832816362381 Step=62 Time=1.3489696979522705
#
# EP322 EpisodeReward=-5 TotalLoss=0.17973481118679047 Step=62 Time=1.3060314655303955
#
# EP323 EpisodeReward=-5 TotalLoss=0.16200664639472961 Step=62 Time=1.4111526012420654
#
# EP324 EpisodeReward=-5 TotalLoss=1.624585509300232 Step=59 Time=1.2775697708129883
#
# EP325 EpisodeReward=-5 TotalLoss=0.2758542001247406 Step=62 Time=1.2821779251098633
#
# EP326 EpisodeReward=-5 TotalLoss=0.18738499283790588 Step=62 Time=1.336695909500122
#
# EP327 EpisodeReward=-5 TotalLoss=0.1437121480703354 Step=62 Time=1.317678689956665
#
# EP328 EpisodeReward=-5 TotalLoss=0.5901437997817993 Step=62 Time=1.3328568935394287
#
# EP329 EpisodeReward=-5 TotalLoss=0.5219211578369141 Step=61 Time=1.271162509918213
#
# EP330 EpisodeReward=-5 TotalLoss=0.5115960836410522 Step=62 Time=1.3376202583312988
#
# EP331 EpisodeReward=-5 TotalLoss=0.14947283267974854 Step=62 Time=1.209315538406372
#
# EP332 EpisodeReward=-5 TotalLoss=0.8596653342247009 Step=62 Time=1.3567261695861816
#
# EP333 EpisodeReward=-5 TotalLoss=0.4393426775932312 Step=62 Time=1.4392967224121094
#
# EP334 EpisodeReward=-5 TotalLoss=0.2132578343153 Step=62 Time=1.2995641231536865
#
# EP335 EpisodeReward=-5 TotalLoss=0.30861034989356995 Step=62 Time=1.276296615600586
#
# EP336 EpisodeReward=-5 TotalLoss=0.2134474366903305 Step=62 Time=1.3134281635284424
#
# EP337 EpisodeReward=-5 TotalLoss=0.14629678428173065 Step=62 Time=1.374767780303955
#
# EP338 EpisodeReward=-5 TotalLoss=0.3377285599708557 Step=62 Time=1.2966196537017822
#
# EP339 EpisodeReward=-5 TotalLoss=0.13758032023906708 Step=56 Time=1.1828367710113525
#
# EP340 EpisodeReward=-5 TotalLoss=0.24768397212028503 Step=62 Time=1.3514835834503174
#
# EP341 EpisodeReward=-5 TotalLoss=0.10967148840427399 Step=59 Time=1.2636868953704834
#
# EP342 EpisodeReward=-5 TotalLoss=0.14206525683403015 Step=62 Time=1.328803300857544
#
# EP343 EpisodeReward=-5 TotalLoss=0.06631320714950562 Step=65 Time=1.518446445465088
#
# EP344 EpisodeReward=-5 TotalLoss=0.39338821172714233 Step=57 Time=1.1950185298919678
#
# EP345 EpisodeReward=-5 TotalLoss=0.08821669220924377 Step=62 Time=1.3524479866027832
#
# EP346 EpisodeReward=-5 TotalLoss=0.11310229450464249 Step=62 Time=1.292804479598999
#
# EP347 EpisodeReward=-5 TotalLoss=0.510392427444458 Step=62 Time=1.2996366024017334
#
# EP348 EpisodeReward=-5 TotalLoss=0.1359780877828598 Step=62 Time=1.3007161617279053
#
# EP349 EpisodeReward=-5 TotalLoss=0.07538802921772003 Step=62 Time=1.3284046649932861
#
# EP350 EpisodeReward=-5 TotalLoss=0.18596947193145752 Step=62 Time=1.1215522289276123
#
# EP351 EpisodeReward=-5 TotalLoss=0.18084007501602173 Step=59 Time=1.2246525287628174
#
# EP352 EpisodeReward=-5 TotalLoss=0.1239660456776619 Step=62 Time=1.2701783180236816
#
# EP353 EpisodeReward=-5 TotalLoss=1.380988359451294 Step=62 Time=1.447939395904541
#
# EP354 EpisodeReward=-5 TotalLoss=0.8685881495475769 Step=63 Time=1.3021137714385986
#
# EP355 EpisodeReward=-5 TotalLoss=0.33188098669052124 Step=59 Time=1.3520300388336182
#
# EP356 EpisodeReward=-5 TotalLoss=0.3846279978752136 Step=62 Time=1.2692537307739258
#
# EP357 EpisodeReward=-5 TotalLoss=0.1703941971063614 Step=62 Time=1.3311028480529785
#
# EP358 EpisodeReward=-5 TotalLoss=0.2114132195711136 Step=62 Time=1.343390703201294
#
# EP359 EpisodeReward=-5 TotalLoss=0.17475023865699768 Step=62 Time=1.2864229679107666
#
# EP360 EpisodeReward=-5 TotalLoss=0.6345556974411011 Step=62 Time=1.2598974704742432
#
# EP361 EpisodeReward=-5 TotalLoss=0.06467977166175842 Step=51 Time=1.1576495170593262
#
# EP362 EpisodeReward=-5 TotalLoss=0.307395339012146 Step=62 Time=1.2939178943634033
#
# EP363 EpisodeReward=-5 TotalLoss=0.5168877840042114 Step=62 Time=1.3009958267211914
#
# EP364 EpisodeReward=-5 TotalLoss=0.16801603138446808 Step=62 Time=1.4922678470611572
#
# EP365 EpisodeReward=-5 TotalLoss=0.10537305474281311 Step=62 Time=1.3912057876586914
#
# EP366 EpisodeReward=-5 TotalLoss=1.1858733892440796 Step=59 Time=1.1282920837402344
#
# EP367 EpisodeReward=-5 TotalLoss=0.19364836812019348 Step=62 Time=1.2954294681549072
#
# EP368 EpisodeReward=-5 TotalLoss=0.17126618325710297 Step=62 Time=1.3276636600494385
#
# EP369 EpisodeReward=-5 TotalLoss=0.0683700293302536 Step=62 Time=1.3362913131713867
#
# EP370 EpisodeReward=-5 TotalLoss=0.27681413292884827 Step=59 Time=1.4349908828735352
#
# EP371 EpisodeReward=-5 TotalLoss=0.1391877830028534 Step=62 Time=1.3633201122283936
#
# EP372 EpisodeReward=-5 TotalLoss=0.22524486482143402 Step=62 Time=1.2569329738616943
#
# EP373 EpisodeReward=-5 TotalLoss=0.11544555425643921 Step=59 Time=1.1774115562438965
#
# EP374 EpisodeReward=-5 TotalLoss=0.1404542177915573 Step=54 Time=1.3486201763153076
#
# EP375 EpisodeReward=-5 TotalLoss=0.3188968896865845 Step=62 Time=1.2167866230010986
#
# EP376 EpisodeReward=-5 TotalLoss=0.7703374624252319 Step=58 Time=1.2119789123535156
#
# EP377 EpisodeReward=-5 TotalLoss=0.06677059829235077 Step=62 Time=1.3836002349853516
#
# EP378 EpisodeReward=-5 TotalLoss=0.6423549652099609 Step=62 Time=1.3022022247314453
#
# EP379 EpisodeReward=-5 TotalLoss=0.1935584843158722 Step=51 Time=1.091181755065918
#
# EP380 EpisodeReward=-5 TotalLoss=0.17268982529640198 Step=62 Time=1.3324310779571533
#
# EP381 EpisodeReward=-5 TotalLoss=1.134919285774231 Step=55 Time=1.0777523517608643
#
# EP382 EpisodeReward=-5 TotalLoss=0.1212545707821846 Step=62 Time=1.3084285259246826
#
# EP383 EpisodeReward=-5 TotalLoss=0.3356933891773224 Step=57 Time=1.1699230670928955
#
# EP384 EpisodeReward=-5 TotalLoss=0.3838112950325012 Step=60 Time=1.5059499740600586
#
# EP385 EpisodeReward=-5 TotalLoss=0.2666034996509552 Step=54 Time=1.0752685070037842
#
# EP386 EpisodeReward=-5 TotalLoss=0.2675763666629791 Step=62 Time=1.3152475357055664
#
# EP387 EpisodeReward=-5 TotalLoss=0.0921260416507721 Step=62 Time=1.507683277130127
#
# EP388 EpisodeReward=-5 TotalLoss=0.18106204271316528 Step=62 Time=1.2619044780731201
#
# EP389 EpisodeReward=-5 TotalLoss=0.21320439875125885 Step=62 Time=1.3593571186065674
#
# EP390 EpisodeReward=-5 TotalLoss=0.3171878457069397 Step=53 Time=1.1457328796386719
#
# EP391 EpisodeReward=-5 TotalLoss=0.5556143522262573 Step=62 Time=1.2344107627868652
#
# EP392 EpisodeReward=-5 TotalLoss=0.30668753385543823 Step=62 Time=1.2321970462799072
#
# EP393 EpisodeReward=-5 TotalLoss=0.3204375207424164 Step=62 Time=1.3519387245178223
#
# EP394 EpisodeReward=-4 TotalLoss=0.5784933567047119 Step=74 Time=1.5347819328308105
#
# EP395 EpisodeReward=-5 TotalLoss=0.6485183238983154 Step=62 Time=1.4047887325286865
#
# EP396 EpisodeReward=-5 TotalLoss=1.7573673725128174 Step=62 Time=1.3652534484863281
#
# EP397 EpisodeReward=-5 TotalLoss=0.2611328065395355 Step=62 Time=1.2603344917297363
#
# EP398 EpisodeReward=-5 TotalLoss=0.4049419164657593 Step=62 Time=1.2530765533447266
#
# EP399 EpisodeReward=-5 TotalLoss=1.4490556716918945 Step=62 Time=1.2880260944366455
#
# EP400 EpisodeReward=-5 TotalLoss=0.39534682035446167 Step=62 Time=1.3919987678527832
#
# EP401 EpisodeReward=-5 TotalLoss=0.052830129861831665 Step=62 Time=1.316016674041748
#
# EP402 EpisodeReward=-5 TotalLoss=1.0706254243850708 Step=62 Time=1.270817756652832
#
# EP403 EpisodeReward=-5 TotalLoss=0.3079316318035126 Step=62 Time=1.4168479442596436
#
# EP404 EpisodeReward=-5 TotalLoss=0.7341476082801819 Step=62 Time=1.2340185642242432
#
# EP405 EpisodeReward=-5 TotalLoss=0.26712292432785034 Step=62 Time=1.3899362087249756
#
# EP406 EpisodeReward=-5 TotalLoss=0.2677658796310425 Step=58 Time=1.1717915534973145
#
# EP407 EpisodeReward=-5 TotalLoss=0.2312798947095871 Step=62 Time=1.3236734867095947
#
# EP408 EpisodeReward=-5 TotalLoss=0.2067049741744995 Step=62 Time=1.2403950691223145
#
# EP409 EpisodeReward=-5 TotalLoss=0.4501919746398926 Step=59 Time=1.313180685043335
#
# EP410 EpisodeReward=-5 TotalLoss=0.060267865657806396 Step=62 Time=1.3019099235534668
#
# EP411 EpisodeReward=-5 TotalLoss=0.07355797290802002 Step=62 Time=1.3487391471862793
#
# EP412 EpisodeReward=-5 TotalLoss=0.14273808896541595 Step=62 Time=1.290989637374878
#
# EP413 EpisodeReward=-5 TotalLoss=0.170988067984581 Step=62 Time=1.1758880615234375
#
# EP414 EpisodeReward=-5 TotalLoss=0.5599038600921631 Step=62 Time=1.3030741214752197
#
# EP415 EpisodeReward=-5 TotalLoss=0.04610110819339752 Step=62 Time=1.529207706451416
#
# EP416 EpisodeReward=-4 TotalLoss=0.8625004887580872 Step=76 Time=1.5015637874603271
#
# EP417 EpisodeReward=-5 TotalLoss=0.6051793098449707 Step=62 Time=1.2454869747161865
#
# EP418 EpisodeReward=-5 TotalLoss=0.9538373947143555 Step=62 Time=1.271310567855835
#
# EP419 EpisodeReward=-5 TotalLoss=0.5273352861404419 Step=65 Time=1.3918375968933105
#
# EP420 EpisodeReward=-5 TotalLoss=0.3954433500766754 Step=62 Time=1.316103219985962
#
# EP421 EpisodeReward=-5 TotalLoss=0.6056331396102905 Step=62 Time=1.2645533084869385
#
# EP422 EpisodeReward=-5 TotalLoss=1.8272552490234375 Step=59 Time=1.2541756629943848
#
# EP423 EpisodeReward=-5 TotalLoss=0.36667540669441223 Step=62 Time=1.380563735961914
#
# EP424 EpisodeReward=-5 TotalLoss=0.3944864273071289 Step=62 Time=1.3049750328063965
#
# EP425 EpisodeReward=-4 TotalLoss=0.8460581302642822 Step=73 Time=1.6996972560882568
#
# EP426 EpisodeReward=-5 TotalLoss=0.4156900644302368 Step=56 Time=1.1561529636383057
#
# EP427 EpisodeReward=-5 TotalLoss=0.7575410604476929 Step=62 Time=1.2631571292877197
#
# EP428 EpisodeReward=-5 TotalLoss=0.3917711079120636 Step=62 Time=1.2968533039093018
#
# EP429 EpisodeReward=-5 TotalLoss=0.19732454419136047 Step=62 Time=1.3011789321899414
#
# EP430 EpisodeReward=-5 TotalLoss=0.14929446578025818 Step=62 Time=1.3464579582214355
#
# EP431 EpisodeReward=-5 TotalLoss=0.3941837549209595 Step=62 Time=1.3617126941680908
#
# EP432 EpisodeReward=-4 TotalLoss=0.36623331904411316 Step=67 Time=1.3546457290649414
#
# EP433 EpisodeReward=-4 TotalLoss=0.4877660870552063 Step=69 Time=1.5989367961883545
#
# EP434 EpisodeReward=-5 TotalLoss=0.04173856973648071 Step=59 Time=1.1966290473937988
#
# EP435 EpisodeReward=-5 TotalLoss=0.06448151171207428 Step=62 Time=1.4963531494140625
#
# EP436 EpisodeReward=-5 TotalLoss=0.45604634284973145 Step=62 Time=1.3341825008392334
#
# EP437 EpisodeReward=-5 TotalLoss=0.0970761850476265 Step=60 Time=1.281811237335205
#
# EP438 EpisodeReward=-5 TotalLoss=0.3730592727661133 Step=63 Time=1.3142714500427246
#
# EP439 EpisodeReward=-5 TotalLoss=0.21684876084327698 Step=62 Time=1.3354809284210205
#
# EP440 EpisodeReward=-5 TotalLoss=0.43059206008911133 Step=62 Time=1.1929900646209717
#
# EP441 EpisodeReward=-5 TotalLoss=0.20084106922149658 Step=62 Time=1.298468828201294
#
# EP442 EpisodeReward=-5 TotalLoss=0.822028636932373 Step=62 Time=1.5078976154327393
#
# EP443 EpisodeReward=-5 TotalLoss=0.10394510626792908 Step=62 Time=1.3188772201538086
#
# EP444 EpisodeReward=-5 TotalLoss=0.21424373984336853 Step=62 Time=1.26920485496521
#
# EP445 EpisodeReward=-5 TotalLoss=0.10611500591039658 Step=62 Time=1.560011625289917
#
# EP446 EpisodeReward=-5 TotalLoss=0.0780174657702446 Step=62 Time=1.315922737121582
#
# EP447 EpisodeReward=-5 TotalLoss=0.042187437415122986 Step=52 Time=1.0281496047973633
#
# EP448 EpisodeReward=-5 TotalLoss=0.2288965880870819 Step=62 Time=1.2713751792907715
#
# EP449 EpisodeReward=-5 TotalLoss=0.4549815058708191 Step=62 Time=1.2646698951721191
#
# EP450 EpisodeReward=-5 TotalLoss=0.13453835248947144 Step=58 Time=1.165285587310791
#
# EP451 EpisodeReward=-5 TotalLoss=0.3996897339820862 Step=51 Time=1.1828997135162354
#
# EP452 EpisodeReward=-5 TotalLoss=0.1942281872034073 Step=62 Time=1.2272822856903076
#
# EP453 EpisodeReward=-4 TotalLoss=0.5231630802154541 Step=67 Time=1.4084241390228271
#
# EP454 EpisodeReward=-5 TotalLoss=0.25237223505973816 Step=62 Time=1.2996883392333984
#
# EP455 EpisodeReward=-5 TotalLoss=1.9192941188812256 Step=62 Time=1.452683687210083
#
# EP456 EpisodeReward=-5 TotalLoss=0.16380956768989563 Step=62 Time=1.2622888088226318
#
# EP457 EpisodeReward=-5 TotalLoss=0.4862191677093506 Step=62 Time=1.260572910308838
#
# EP458 EpisodeReward=-5 TotalLoss=0.18122924864292145 Step=62 Time=1.2443807125091553
#
# EP459 EpisodeReward=-5 TotalLoss=0.7172560691833496 Step=62 Time=1.366528034210205
#
# EP460 EpisodeReward=-5 TotalLoss=0.5820916891098022 Step=62 Time=1.2840709686279297
#
# EP461 EpisodeReward=-5 TotalLoss=0.326779305934906 Step=62 Time=1.2907626628875732
#
# EP462 EpisodeReward=-5 TotalLoss=0.2091037482023239 Step=62 Time=1.415292501449585
#
# EP463 EpisodeReward=-5 TotalLoss=0.307888925075531 Step=62 Time=1.2913048267364502
#
# EP464 EpisodeReward=-4.0 TotalLoss=0.007705122232437134 Step=66 Time=1.3290679454803467
#
# EP465 EpisodeReward=-5 TotalLoss=0.17444540560245514 Step=62 Time=1.5055737495422363
#
# EP466 EpisodeReward=-4 TotalLoss=2.453828811645508 Step=91 Time=1.832932949066162
#
# EP467 EpisodeReward=-5 TotalLoss=0.2720329165458679 Step=55 Time=1.1901493072509766
#
# EP468 EpisodeReward=-5 TotalLoss=0.3850892186164856 Step=62 Time=1.2916247844696045
#
# EP469 EpisodeReward=-5 TotalLoss=0.1416795402765274 Step=59 Time=1.232879877090454
#
# EP470 EpisodeReward=-4 TotalLoss=1.196637749671936 Step=98 Time=2.0801117420196533
#
# EP471 EpisodeReward=-5 TotalLoss=0.43807077407836914 Step=62 Time=1.1750459671020508
#
# EP472 EpisodeReward=-5 TotalLoss=0.06849431991577148 Step=62 Time=1.2852489948272705
#
# EP473 EpisodeReward=-5 TotalLoss=0.8679507970809937 Step=62 Time=1.343048334121704
#
# EP474 EpisodeReward=-4 TotalLoss=0.7903778553009033 Step=74 Time=1.5258979797363281
#
# EP475 EpisodeReward=-5 TotalLoss=0.07320363819599152 Step=62 Time=1.276672124862671
#
# EP476 EpisodeReward=-5 TotalLoss=0.05898071825504303 Step=62 Time=1.260960578918457
#
# EP477 EpisodeReward=-5 TotalLoss=0.05176436901092529 Step=62 Time=1.3059749603271484
#
# EP478 EpisodeReward=-5 TotalLoss=0.23314960300922394 Step=62 Time=1.1948111057281494
#
# EP479 EpisodeReward=-4 TotalLoss=0.5489793419837952 Step=69 Time=1.4985988140106201
#
# EP480 EpisodeReward=-5 TotalLoss=0.0452084094285965 Step=62 Time=1.2410006523132324
#
# EP481 EpisodeReward=-5 TotalLoss=0.23219329118728638 Step=62 Time=1.4766623973846436
#
# EP482 EpisodeReward=-5 TotalLoss=0.04204926639795303 Step=62 Time=1.3502166271209717
#
# EP483 EpisodeReward=-5 TotalLoss=0.2603464722633362 Step=62 Time=1.3161704540252686
#
# EP484 EpisodeReward=-5 TotalLoss=0.13262790441513062 Step=62 Time=1.4644675254821777
#
# EP485 EpisodeReward=-5 TotalLoss=0.19805178046226501 Step=62 Time=1.2875428199768066
#
# EP486 EpisodeReward=-5 TotalLoss=0.046313442289829254 Step=62 Time=1.266336441040039
#
# EP487 EpisodeReward=-5 TotalLoss=0.08601680397987366 Step=62 Time=1.2521145343780518
#
# EP488 EpisodeReward=-5 TotalLoss=0.18664611876010895 Step=62 Time=1.313849925994873
#
# EP489 EpisodeReward=-5 TotalLoss=0.8024404048919678 Step=62 Time=1.3066766262054443
#
# EP490 EpisodeReward=-5 TotalLoss=0.047908440232276917 Step=62 Time=1.187967300415039
#
# EP491 EpisodeReward=-5 TotalLoss=0.09258121252059937 Step=62 Time=1.2781319618225098
#
# EP492 EpisodeReward=-5 TotalLoss=0.10066219419240952 Step=60 Time=1.2164700031280518
#
# EP493 EpisodeReward=-5 TotalLoss=0.161819189786911 Step=62 Time=1.2008693218231201
#
# EP494 EpisodeReward=-4 TotalLoss=0.4297773540019989 Step=67 Time=1.6493735313415527
#
# EP495 EpisodeReward=-5 TotalLoss=0.09368205070495605 Step=62 Time=1.3968496322631836
#
# EP496 EpisodeReward=-5 TotalLoss=0.33258169889450073 Step=65 Time=1.290785551071167
#
# EP497 EpisodeReward=-5 TotalLoss=0.3538513481616974 Step=62 Time=1.4361913204193115
#
# EP498 EpisodeReward=-5 TotalLoss=0.10860735177993774 Step=62 Time=1.2796168327331543
#
# EP499 EpisodeReward=-5 TotalLoss=0.07353360205888748 Step=61 Time=1.2232017517089844
#
# EP500 EpisodeReward=-5 TotalLoss=0.6665281057357788 Step=62 Time=1.3150665760040283
#
# EP501 EpisodeReward=-5 TotalLoss=0.8202266693115234 Step=64 Time=1.4131684303283691
#
# EP502 EpisodeReward=-5 TotalLoss=0.451354056596756 Step=60 Time=1.2665786743164062
#
# EP503 EpisodeReward=-5 TotalLoss=0.3269646465778351 Step=62 Time=1.2547094821929932
#
# EP504 EpisodeReward=-5 TotalLoss=0.1592416912317276 Step=62 Time=1.567168951034546
#
# EP505 EpisodeReward=-5 TotalLoss=0.23263701796531677 Step=62 Time=1.3014328479766846
#
# EP506 EpisodeReward=-5 TotalLoss=0.27473005652427673 Step=65 Time=1.4295969009399414
#
# EP507 EpisodeReward=-3 TotalLoss=1.916825771331787 Step=108 Time=2.316556453704834
#
# EP508 EpisodeReward=-5 TotalLoss=0.09363259375095367 Step=62 Time=1.2749385833740234
#
# EP509 EpisodeReward=-4 TotalLoss=0.8223703503608704 Step=70 Time=1.5400142669677734
#
# EP510 EpisodeReward=-5 TotalLoss=0.03241092711687088 Step=62 Time=1.3176751136779785
#
# EP511 EpisodeReward=-5 TotalLoss=0.9899930357933044 Step=62 Time=1.2699058055877686
#
# EP512 EpisodeReward=-5 TotalLoss=0.36831527948379517 Step=57 Time=1.1975350379943848
#
# EP513 EpisodeReward=-5 TotalLoss=0.1873367428779602 Step=62 Time=1.213747501373291
#
# EP514 EpisodeReward=-4 TotalLoss=2.077751398086548 Step=98 Time=2.1588246822357178
#
# EP515 EpisodeReward=-5 TotalLoss=0.31959080696105957 Step=62 Time=1.2490146160125732
#
# EP516 EpisodeReward=-5 TotalLoss=0.15870389342308044 Step=62 Time=1.31697678565979
#
# EP517 EpisodeReward=-5 TotalLoss=0.34109434485435486 Step=62 Time=1.42649507522583
#
# EP518 EpisodeReward=-5 TotalLoss=0.15404799580574036 Step=62 Time=1.357597827911377
#
# EP519 EpisodeReward=-5 TotalLoss=0.13610953092575073 Step=62 Time=1.2476625442504883
#
# EP520 EpisodeReward=-5 TotalLoss=0.1284666657447815 Step=62 Time=1.2930324077606201
#
# EP521 EpisodeReward=-4.0 TotalLoss=0.07434335350990295 Step=66 Time=1.3953444957733154
#
# EP522 EpisodeReward=-5 TotalLoss=0.4907853901386261 Step=65 Time=1.3611438274383545
#
# EP523 EpisodeReward=-5 TotalLoss=0.07587458938360214 Step=53 Time=1.3377456665039062
#
# EP524 EpisodeReward=-4 TotalLoss=1.475113868713379 Step=77 Time=1.6629559993743896
#
# EP525 EpisodeReward=-4 TotalLoss=2.0735747814178467 Step=98 Time=1.9484481811523438
#
# EP526 EpisodeReward=-5 TotalLoss=0.19621586799621582 Step=53 Time=1.1074278354644775
#
# EP527 EpisodeReward=-4 TotalLoss=0.21348649263381958 Step=68 Time=1.504887580871582
#
# EP528 EpisodeReward=-5 TotalLoss=0.07411956787109375 Step=62 Time=1.3828864097595215
#
# EP529 EpisodeReward=-5 TotalLoss=0.7150450944900513 Step=62 Time=1.3854146003723145
#
# EP530 EpisodeReward=-5 TotalLoss=0.060427721589803696 Step=62 Time=1.2615337371826172
#
# EP531 EpisodeReward=-5 TotalLoss=0.038828104734420776 Step=64 Time=1.310514211654663
#
# EP532 EpisodeReward=-4 TotalLoss=2.019943952560425 Step=98 Time=2.2179858684539795
#
# EP533 EpisodeReward=-5 TotalLoss=0.14298489689826965 Step=62 Time=1.1385979652404785
#
# EP534 EpisodeReward=-4 TotalLoss=2.0147597789764404 Step=97 Time=1.9994325637817383
#
# EP535 EpisodeReward=-4 TotalLoss=0.34641581773757935 Step=71 Time=1.5449435710906982
#
# EP536 EpisodeReward=-5 TotalLoss=0.07344475388526917 Step=62 Time=1.251875877380371
#
# EP537 EpisodeReward=-4 TotalLoss=3.27634859085083 Step=98 Time=2.0393810272216797
#
# EP538 EpisodeReward=-3 TotalLoss=1.363358974456787 Step=134 Time=2.6507346630096436
#
# EP539 EpisodeReward=-5 TotalLoss=0.6317431926727295 Step=62 Time=1.3804640769958496
#
# EP540 EpisodeReward=-5 TotalLoss=0.8978283405303955 Step=62 Time=1.3426322937011719
#
# EP541 EpisodeReward=-4 TotalLoss=0.9730371236801147 Step=98 Time=1.9642894268035889
#
# EP542 EpisodeReward=-4 TotalLoss=0.4960786700248718 Step=73 Time=1.523421287536621
#
# EP543 EpisodeReward=-5 TotalLoss=0.33227816224098206 Step=62 Time=1.1330149173736572
#
# EP544 EpisodeReward=-4 TotalLoss=0.9357370138168335 Step=98 Time=2.065333366394043
#
# EP545 EpisodeReward=-5 TotalLoss=0.23206941783428192 Step=62 Time=1.2871489524841309
#
# EP546 EpisodeReward=-4 TotalLoss=0.4151802361011505 Step=68 Time=1.3935134410858154
#
# EP547 EpisodeReward=-4 TotalLoss=0.9305135011672974 Step=94 Time=1.9945807456970215
#
# EP548 EpisodeReward=-5 TotalLoss=0.5252463817596436 Step=64 Time=1.383223056793213
#
# EP549 EpisodeReward=-5 TotalLoss=0.19516873359680176 Step=62 Time=1.3727927207946777
#
# EP550 EpisodeReward=-5 TotalLoss=0.10943064093589783 Step=62 Time=1.2917413711547852
#
# EP551 EpisodeReward=-5 TotalLoss=0.09248071163892746 Step=62 Time=1.2528231143951416
#
# EP552 EpisodeReward=-5 TotalLoss=0.3198848366737366 Step=64 Time=1.298292636871338
#
# EP553 EpisodeReward=-5 TotalLoss=0.4768603444099426 Step=62 Time=1.3551356792449951
#
# EP554 EpisodeReward=-5 TotalLoss=0.12535852193832397 Step=62 Time=1.2674484252929688
#
# EP555 EpisodeReward=-5 TotalLoss=0.6393319368362427 Step=63 Time=1.3656842708587646
#
# EP556 EpisodeReward=-5 TotalLoss=0.12964436411857605 Step=62 Time=1.4331796169281006
#
# EP557 EpisodeReward=-4 TotalLoss=4.290282249450684 Step=98 Time=2.2096877098083496
#
# EP558 EpisodeReward=-5 TotalLoss=0.11179760098457336 Step=62 Time=1.316666841506958
#
# EP559 EpisodeReward=-5 TotalLoss=0.9264763593673706 Step=62 Time=1.2730257511138916
#
# EP560 EpisodeReward=-5 TotalLoss=0.16429363191127777 Step=62 Time=1.2308776378631592
#
# EP561 EpisodeReward=-5 TotalLoss=0.34682315587997437 Step=62 Time=1.3355815410614014
#
# EP562 EpisodeReward=-4 TotalLoss=0.4911983609199524 Step=71 Time=1.51358962059021
#
# EP563 EpisodeReward=-4 TotalLoss=0.3895145654678345 Step=67 Time=1.3664424419403076
#
# EP564 EpisodeReward=-5 TotalLoss=0.17460383474826813 Step=62 Time=1.2451200485229492
#
# ...
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=636_CUR_EPISODE=1391/assets
# EP1392 EpisodeReward=-1 TotalLoss=0.588954508304596 Step=181 Time=3.022273063659668
#
# EP1393 EpisodeReward=6 TotalLoss=0.43295085430145264 Step=473 Time=7.9794228076934814
#
# EP1394 EpisodeReward=166 TotalLoss=0.29465994238853455 Step=6503 Time=110.10937094688416
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=166_CUR_EPISODE=1394/assets
# EP1395 EpisodeReward=77 TotalLoss=0.11562174558639526 Step=3119 Time=52.427586793899536
#
# EP1396 EpisodeReward=104 TotalLoss=0.4752829372882843 Step=4166 Time=71.10204911231995
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=104_CUR_EPISODE=1396/assets
# EP1397 EpisodeReward=152 TotalLoss=0.3858293890953064 Step=5952 Time=101.09071898460388
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=152_CUR_EPISODE=1397/assets
# EP1398 EpisodeReward=43 TotalLoss=0.12132840603590012 Step=1838 Time=30.895627737045288
#
# EP1399 EpisodeReward=63 TotalLoss=0.1542099118232727 Step=2620 Time=44.29974675178528
#
# EP1400 EpisodeReward=10 TotalLoss=0.18565602600574493 Step=591 Time=9.776923418045044
#
# EP1401 EpisodeReward=39 TotalLoss=0.13284292817115784 Step=1716 Time=28.965548276901245
#
# EP1402 EpisodeReward=8 TotalLoss=0.2461872100830078 Step=523 Time=8.962929964065552
#
# EP1403 EpisodeReward=225 TotalLoss=0.393072247505188 Step=8722 Time=147.06486296653748
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=225_CUR_EPISODE=1403/assets
# EP1404 EpisodeReward=254 TotalLoss=0.23545916378498077 Step=9816 Time=165.94931936264038
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=254_CUR_EPISODE=1404/assets
# EP1405 EpisodeReward=86 TotalLoss=0.05674233287572861 Step=3488 Time=58.85302209854126
#
# EP1406 EpisodeReward=282 TotalLoss=0.17777910828590393 Step=10869 Time=184.23303604125977
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=282_CUR_EPISODE=1406/assets
# EP1407 EpisodeReward=2 TotalLoss=0.07482238858938217 Step=324 Time=5.699286937713623
#
# EP1408 EpisodeReward=597 TotalLoss=0.3903900384902954 Step=22734 Time=384.9980640411377
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=597_CUR_EPISODE=1408/assets
# EP1409 EpisodeReward=390 TotalLoss=0.24205464124679565 Step=14937 Time=253.40776705741882
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=390_CUR_EPISODE=1409/assets
# EP1410 EpisodeReward=354 TotalLoss=0.26428020000457764 Step=13581 Time=229.9066972732544
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=354_CUR_EPISODE=1410/assets
# EP1411 EpisodeReward=806.0 TotalLoss=0.863659143447876 Step=30576 Time=518.2381558418274
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=806.0_CUR_EPISODE=1411/assets
# EP1412 EpisodeReward=15 TotalLoss=0.1706458330154419 Step=812 Time=13.85122561454773
#
# EP1413 EpisodeReward=185 TotalLoss=0.12186810374259949 Step=7217 Time=122.35841393470764
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=185_CUR_EPISODE=1413/assets
# EP1414 EpisodeReward=428 TotalLoss=0.3938717246055603 Step=16370 Time=277.922726392746
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=428_CUR_EPISODE=1414/assets
# EP1415 EpisodeReward=322 TotalLoss=0.47290629148483276 Step=12379 Time=210.68594002723694
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=322_CUR_EPISODE=1415/assets
# EP1416 EpisodeReward=471 TotalLoss=0.34824299812316895 Step=17988 Time=305.94496154785156
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=471_CUR_EPISODE=1416/assets
# EP1417 EpisodeReward=374 TotalLoss=0.2501215636730194 Step=14336 Time=244.23356366157532
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=374_CUR_EPISODE=1417/assets
# EP1418 EpisodeReward=411 TotalLoss=0.20875927805900574 Step=15728 Time=267.3373792171478
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=411_CUR_EPISODE=1418/assets
# EP1419 EpisodeReward=-4 TotalLoss=0.12588731944561005 Step=98 Time=1.659552812576294
#
# EP1420 EpisodeReward=74 TotalLoss=0.34275752305984497 Step=3036 Time=51.70888829231262
#
# EP1421 EpisodeReward=401 TotalLoss=0.28419366478919983 Step=15353 Time=261.1477246284485
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=401_CUR_EPISODE=1421/assets
# EP1422 EpisodeReward=640.0 TotalLoss=1.0212910175323486 Step=24320 Time=414.1976556777954
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=640.0_CUR_EPISODE=1422/assets
# EP1423 EpisodeReward=1481 TotalLoss=3.984194278717041 Step=56034 Time=953.1887013912201
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1481_CUR_EPISODE=1423/assets
# EP1424 EpisodeReward=396 TotalLoss=0.6768922805786133 Step=15164 Time=258.36796617507935
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=396_CUR_EPISODE=1424/assets
# EP1425 EpisodeReward=1235 TotalLoss=0.7235844135284424 Step=46745 Time=791.2670359611511
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1235_CUR_EPISODE=1425/assets
# EP1426 EpisodeReward=780 TotalLoss=0.381700336933136 Step=29627 Time=502.043790102005
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=780_CUR_EPISODE=1426/assets
# EP1427 EpisodeReward=228 TotalLoss=0.28146815299987793 Step=8815 Time=148.6871702671051
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=228_CUR_EPISODE=1427/assets
# EP1428 EpisodeReward=3 TotalLoss=0.3730466663837433 Step=338 Time=5.568774700164795
#
# EP1429 EpisodeReward=687 TotalLoss=0.5464736223220825 Step=26102 Time=442.7677125930786
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=687_CUR_EPISODE=1429/assets
# EP1430 EpisodeReward=975 TotalLoss=0.5478973388671875 Step=36972 Time=629.4156625270844
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=975_CUR_EPISODE=1430/assets
# EP1431 EpisodeReward=1362 TotalLoss=0.5948959589004517 Step=51519 Time=875.0633070468903
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1362_CUR_EPISODE=1431/assets
# EP1432 EpisodeReward=1553 TotalLoss=0.6126604676246643 Step=58745 Time=1031.7231857776642
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1553_CUR_EPISODE=1432/assets
# EP1433 EpisodeReward=631 TotalLoss=8.214966773986816 Step=24018 Time=415.78232431411743
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=631_CUR_EPISODE=1433/assets
# EP1434 EpisodeReward=-2 TotalLoss=0.5154200792312622 Step=167 Time=2.821582317352295
#
# EP1435 EpisodeReward=62 TotalLoss=0.30211448669433594 Step=2584 Time=43.83872604370117
#
# EP1436 EpisodeReward=1346 TotalLoss=1.0622785091400146 Step=50948 Time=865.1451785564423
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1346_CUR_EPISODE=1436/assets
# EP1437 EpisodeReward=93 TotalLoss=0.06984596699476242 Step=3750 Time=63.433900356292725
#
# EP1438 EpisodeReward=299 TotalLoss=0.12692919373512268 Step=11511 Time=195.5005099773407
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=299_CUR_EPISODE=1438/assets
# EP1439 EpisodeReward=392 TotalLoss=0.18202480673789978 Step=15014 Time=254.40196084976196
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=392_CUR_EPISODE=1439/assets
# EP1440 EpisodeReward=2010 TotalLoss=0.7304965853691101 Step=75957 Time=1286.5216512680054
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=2010_CUR_EPISODE=1440/assets
# EP1441 EpisodeReward=212 TotalLoss=0.2424653172492981 Step=8234 Time=139.7477674484253
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=212_CUR_EPISODE=1441/assets
# EP1442 EpisodeReward=60 TotalLoss=0.2639533281326294 Step=2507 Time=42.01862549781799
#
# EP1443 EpisodeReward=1169 TotalLoss=0.8831185102462769 Step=44281 Time=776.0750970840454
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1169_CUR_EPISODE=1443/assets
# EP1444 EpisodeReward=54 TotalLoss=0.18425697088241577 Step=2279 Time=40.22869896888733
#
# EP1445 EpisodeReward=210 TotalLoss=0.5511627793312073 Step=8157 Time=143.8604416847229
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=210_CUR_EPISODE=1445/assets
# EP1446 EpisodeReward=5700 TotalLoss=2.2619574069976807 Step=214947 Time=3777.550475358963
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=5700_CUR_EPISODE=1446/assets
# EP1447 EpisodeReward=30 TotalLoss=0.11658120900392532 Step=1355 Time=24.029428720474243
#
# EP1448 EpisodeReward=862.0 TotalLoss=0.9028942584991455 Step=32682 Time=574.7208430767059
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=862.0_CUR_EPISODE=1448/assets
# EP1449 EpisodeReward=782 TotalLoss=0.21236245334148407 Step=29704 Time=522.4392876625061
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=782_CUR_EPISODE=1449/assets
# EP1450 EpisodeReward=456 TotalLoss=0.29165321588516235 Step=17423 Time=306.3069498538971
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=456_CUR_EPISODE=1450/assets
# EP1451 EpisodeReward=861 TotalLoss=0.4737352132797241 Step=32651 Time=574.2639939785004
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=861_CUR_EPISODE=1451/assets
# EP1452 EpisodeReward=5 TotalLoss=0.35322296619415283 Step=437 Time=7.576338291168213
#
# EP1453 EpisodeReward=18 TotalLoss=0.2283078134059906 Step=925 Time=16.41898775100708
#
# EP1454 EpisodeReward=18 TotalLoss=0.13002188503742218 Step=925 Time=16.01447105407715
#
# EP1455 EpisodeReward=1485 TotalLoss=1.2550103664398193 Step=56158 Time=1040.5763840675354
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1485_CUR_EPISODE=1455/assets
# EP1456 EpisodeReward=659 TotalLoss=0.662293553352356 Step=25071 Time=485.36082196235657
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=659_CUR_EPISODE=1456/assets
# EP1457 EpisodeReward=1966 TotalLoss=0.6379228830337524 Step=74271 Time=1374.1769108772278
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1966_CUR_EPISODE=1457/assets
# EP1458 EpisodeReward=1523 TotalLoss=0.5515615940093994 Step=57615 Time=1105.4259278774261
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1523_CUR_EPISODE=1458/assets
# EP1459 EpisodeReward=1170 TotalLoss=0.9022842645645142 Step=44317 Time=849.5864281654358
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1170_CUR_EPISODE=1459/assets
# EP1460 EpisodeReward=-1 TotalLoss=0.20162616670131683 Step=210 Time=4.060075044631958
#
# EP1461 EpisodeReward=1445 TotalLoss=0.5486632585525513 Step=54677 Time=1048.0167889595032
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1445_CUR_EPISODE=1461/assets
# EP1462 EpisodeReward=801 TotalLoss=0.27166470885276794 Step=30418 Time=584.8305826187134
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=801_CUR_EPISODE=1462/assets
# EP1463 EpisodeReward=137 TotalLoss=0.17728707194328308 Step=5409 Time=104.09654402732849
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=137_CUR_EPISODE=1463/assets
# EP1464 EpisodeReward=92 TotalLoss=0.13173741102218628 Step=3715 Time=71.68847322463989
#
# EP1465 EpisodeReward=399 TotalLoss=0.1240234225988388 Step=15252 Time=291.18533849716187
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=399_CUR_EPISODE=1465/assets
# EP1466 EpisodeReward=33 TotalLoss=0.11923925578594208 Step=1490 Time=26.51004958152771
#
# EP1467 EpisodeReward=2192 TotalLoss=0.6691343784332275 Step=82814 Time=1410.1649522781372
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=2192_CUR_EPISODE=1467/assets
# EP1468 EpisodeReward=65 TotalLoss=0.08315443247556686 Step=2697 Time=45.45408606529236
#
# EP1469 EpisodeReward=969 TotalLoss=0.4861457943916321 Step=36746 Time=622.1289801597595
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=969_CUR_EPISODE=1469/assets
# EP1470 EpisodeReward=1811 TotalLoss=0.8914918303489685 Step=68463 Time=1159.0666148662567
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1811_CUR_EPISODE=1470/assets
# EP1471 EpisodeReward=-4 TotalLoss=0.9987187385559082 Step=98 Time=1.6709842681884766
#
# EP1472 EpisodeReward=127 TotalLoss=0.6585385203361511 Step=5002 Time=84.48245692253113
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=127_CUR_EPISODE=1472/assets
# EP1473 EpisodeReward=25 TotalLoss=0.1846856027841568 Step=1194 Time=20.299514293670654
#
# EP1474 EpisodeReward=10 TotalLoss=0.2776200771331787 Step=627 Time=10.592543601989746
#
# EP1475 EpisodeReward=837 TotalLoss=0.3032689690589905 Step=31774 Time=536.8961260318756
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=837_CUR_EPISODE=1475/assets
# EP1476 EpisodeReward=1560 TotalLoss=0.43192702531814575 Step=59007 Time=998.7771611213684
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1560_CUR_EPISODE=1476/assets
# EP1477 EpisodeReward=729 TotalLoss=0.2135821282863617 Step=27706 Time=470.19986295700073
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=729_CUR_EPISODE=1477/assets
# EP1478 EpisodeReward=249 TotalLoss=0.21063333749771118 Step=9626 Time=162.66571164131165
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=249_CUR_EPISODE=1478/assets
# EP1479 EpisodeReward=2232 TotalLoss=0.988142728805542 Step=84319 Time=1547.5459458827972
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=2232_CUR_EPISODE=1479/assets
# EP1480 EpisodeReward=1241 TotalLoss=0.49508216977119446 Step=46993 Time=991.6419932842255
#
# INFO:tensorflow:Assets written to: /tf/Competition04/state_a3c_cpu=1_interval=4000/a3c_cpu=1_trainreward=1241_CUR_EPISODE=1480/assets

# %% [markdown]
# # (五)、Conclusion
#
# * 本次比賽的模型雖然是A3C的架構，但整個training的過程，只用單核(A2C)進行training。
# * 在training時要有耐心，episode在1000次以前不容易train起來，在1000次以後整體reward會提升許多。
# * 即便不調整原先reward的設計，用A2C也能train得不錯。
# * 最後模型在TA環境實測，一個episode的reward可以達150萬以上。
